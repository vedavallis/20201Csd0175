# %%
#INE062A01020

# %%
import upstox_client 
import pandas as pd
import numpy as np

# %%
api_instance = upstox_client.HistoryApi()
instrument_key = 'NSE_EQ|INE062A01020'#SBIN str | Key of the instrument NSE_EQ|INE238A01034,NSE_INDEX|Nifty Bank 
interval = 'day'
to_date ='2023-12-05'
from_date ='2023-11-08'
api_version = '2.0' # str | API Version Header
api_response = api_instance.get_historical_candle_data1(instrument_key,interval,to_date,from_date,api_version)

# %%
data=api_response.data.candles
data
# Out:
# [['2023-11-08T00:00:00+05:30', 581.9, 582.6, 579, 580.3, 15434808, 0],
#  ['2023-11-09T00:00:00+05:30', 581, 581.85, 576.5, 578.35, 12434363, 0],
#  ['2023-11-10T00:00:00+05:30', 577.8, 581, 575.4, 579.5, 6773038, 0],
#  ['2023-11-12T00:00:00+05:30', 584.75, 584.75, 580.1, 581.3, 1947722, 0],
#  ['2023-11-13T00:00:00+05:30', 581, 582.5, 575.2, 581.35, 11282362, 0],
#  ['2023-11-15T00:00:00+05:30', 587.25, 588, 582.6, 584.7, 11397676, 0],
#  ['2023-11-16T00:00:00+05:30', 584.7, 588, 582.9, 584.65, 8622660, 0],
#  ['2023-11-17T00:00:00+05:30', 574.5, 574.5, 562.1, 563.05, 37173221, 0],
#  ['2023-11-20T00:00:00+05:30', 564, 566.8, 560.6, 563.75, 12714585, 0],
#  ['2023-11-21T00:00:00+05:30', 566, 566.65, 561, 561.5, 14280013, 0],
#  ['2023-11-22T00:00:00+05:30', 562.95, 564.5, 555.15, 558.95, 14909071, 0],
#  ['2023-11-23T00:00:00+05:30', 561.75, 563.5, 558.3, 559.95, 6376210, 0],
#  ['2023-11-24T00:00:00+05:30', 561.95, 562.45, 559.25, 560.35, 6529851, 0],
#  ['2023-11-28T00:00:00+05:30', 563.6, 565.2, 561.1, 564.45, 8153314, 0],
#  ['2023-11-29T00:00:00+05:30', 568, 569, 565.1, 568.6, 10299034, 0],
#  ['2023-11-30T00:00:00+05:30', 569.75, 570.2, 563.65, 564.75, 19758998, 0],
#  ['2023-12-01T00:00:00+05:30', 567, 574.2, 566.55, 571.75, 10614230, 0],
#  ['2023-12-04T00:00:00+05:30', 588, 596, 584.55, 594.7, 26077882, 0],
#  ['2023-12-05T00:00:00+05:30', 595.05, 611.3, 595.05, 608.25, 36430152, 0]]

# %%
data.reverse()
data=np.array(data)
data=data[:,4]

# %%
data=pd.DataFrame(data)

# %%
# Out:
#                             0       1      2       3       4         5  6
# 18  2023-12-05T00:00:00+05:30  595.05  611.3  595.05  608.25  36430152  0

# %%
df.index = df["Date"]
del df['Unknown']
del df['Date']
df.index=df.index.str.replace("T.*05:30","",regex=True)

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2007-01-02  125.00  126.00  124.30  125.36   4081440
# 2007-01-03  125.00  126.99  123.71  126.49   6825540
# 2007-01-04  127.00  128.00  123.72  124.30   6544400
# 2007-01-05  124.10  125.78  123.31  124.41   6962270
# 2007-01-08  124.88  124.88  120.71  121.37   8747010
# ...            ...     ...     ...     ...       ...
# 2023-11-29  568.00  569.00  565.10  568.60  10299034
# 2023-11-30  569.75  570.20  563.65  564.75  19758998
# 2023-12-01  567.00  574.20  566.55  571.75  10614230
# 2023-12-04  588.00  596.00  584.55  594.70  26077882
# 2023-12-05  595.05  611.30  595.05  608.25  36430152
#
# [4193 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
df.plot.line(y="Close", use_index= True)
# Out:
# <Axes: xlabel='Date'>

# %%
df["Tomorrow"] = df["Close"].shift(-1)

# %%
df
# Out:
#               Open    High     Low   Close    Volume  Tomorrow
# Date
# 2007-01-02  125.00  126.00  124.30  125.36   4081440    126.49
# 2007-01-03  125.00  126.99  123.71  126.49   6825540    124.30
# 2007-01-04  127.00  128.00  123.72  124.30   6544400    124.41
# 2007-01-05  124.10  125.78  123.31  124.41   6962270    121.37
# 2007-01-08  124.88  124.88  120.71  121.37   8747010    117.49
# ...            ...     ...     ...     ...       ...       ...
# 2023-11-29  568.00  569.00  565.10  568.60  10299034    564.75
# 2023-11-30  569.75  570.20  563.65  564.75  19758998    571.75
# 2023-12-01  567.00  574.20  566.55  571.75  10614230    594.70
# 2023-12-04  588.00  596.00  584.55  594.70  26077882    608.25
# 2023-12-05  595.05  611.30  595.05  608.25  36430152       NaN
#
# [4193 rows x 6 columns]

# %%
df.isnull()
# Out:
#              Open   High    Low  Close  Volume  Tomorrow
# Date
# 2007-01-02  False  False  False  False   False     False
# 2007-01-03  False  False  False  False   False     False
# 2007-01-04  False  False  False  False   False     False
# 2007-01-05  False  False  False  False   False     False
# 2007-01-08  False  False  False  False   False     False
# ...           ...    ...    ...    ...     ...       ...
# 2023-11-29  False  False  False  False   False     False
# 2023-11-30  False  False  False  False   False     False
# 2023-12-01  False  False  False  False   False     False
# 2023-12-04  False  False  False  False   False     False
# 2023-12-05  False  False  False  False   False      True
#
# [4193 rows x 6 columns]

# %%
df.dropna(axis=0)
# Out:
#               Open    High     Low   Close    Volume  Tomorrow
# Date
# 2007-01-02  125.00  126.00  124.30  125.36   4081440    126.49
# 2007-01-03  125.00  126.99  123.71  126.49   6825540    124.30
# 2007-01-04  127.00  128.00  123.72  124.30   6544400    124.41
# 2007-01-05  124.10  125.78  123.31  124.41   6962270    121.37
# 2007-01-08  124.88  124.88  120.71  121.37   8747010    117.49
# ...            ...     ...     ...     ...       ...       ...
# 2023-11-28  563.60  565.20  561.10  564.45   8153314    568.60
# 2023-11-29  568.00  569.00  565.10  568.60  10299034    564.75
# 2023-11-30  569.75  570.20  563.65  564.75  19758998    571.75
# 2023-12-01  567.00  574.20  566.55  571.75  10614230    594.70
# 2023-12-04  588.00  596.00  584.55  594.70  26077882    608.25
#
# [4192 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Open        0
# High        0
# Low         0
# Close       0
# Volume      0
# Tomorrow    1
# dtype: int64

# %%
df["Target"] = (df['Tomorrow'] > df['Close']).astype(int)

# %%
df
# Out:
#               Open    High     Low   Close    Volume  Tomorrow  Target
# Date
# 2007-01-02  125.00  126.00  124.30  125.36   4081440    126.49       1
# 2007-01-03  125.00  126.99  123.71  126.49   6825540    124.30       0
# 2007-01-04  127.00  128.00  123.72  124.30   6544400    124.41       1
# 2007-01-05  124.10  125.78  123.31  124.41   6962270    121.37       0
# 2007-01-08  124.88  124.88  120.71  121.37   8747010    117.49       0
# ...            ...     ...     ...     ...       ...       ...     ...
# 2023-11-29  568.00  569.00  565.10  568.60  10299034    564.75       0
# 2023-11-30  569.75  570.20  563.65  564.75  19758998    571.75       1
# 2023-12-01  567.00  574.20  566.55  571.75  10614230    594.70       1
# 2023-12-04  588.00  596.00  584.55  594.70  26077882    608.25       1
# 2023-12-05  595.05  611.30  595.05  608.25  36430152       NaN       0
#
# [4193 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = df.iloc[:-100]
test = df.iloc[-100:]

# %%
predictors = ['Close']

# %%
train[predictors]
# Out:
#              Close
# Date
# 2007-01-02  125.36
# 2007-01-03  126.49
# 2007-01-04  124.30
# 2007-01-05  124.41
# 2007-01-08  121.37
# ...            ...
# 2023-07-05  590.60
# 2023-07-06  592.50
# 2023-07-07  593.60
# 2023-07-10  592.60
# 2023-07-11  588.55
#
# [4093 rows x 1 columns]

# %%
model.fit(train[predictors], train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
# Out:
#              Close    Volume    Open    High     Low
# Date
# 2023-07-12  589.25  16029716  589.00  594.50  588.20
# 2023-07-13  585.65  20024503  594.90  598.00  583.35
# 2023-07-14  584.40  12190152  586.75  591.30  580.70
# 2023-07-17  601.10  19378986  587.00  602.85  584.20
# 2023-07-18  592.35  25757209  603.05  604.05  588.75
# ...            ...       ...     ...     ...     ...
# 2023-11-29  568.60  10299034  568.00  569.00  565.10
# 2023-11-30  564.75  19758998  569.75  570.20  563.65
# 2023-12-01  571.75  10614230  567.00  574.20  566.55
# 2023-12-04  594.70  26077882  588.00  596.00  584.55
# 2023-12-05  608.25  36430152  595.05  611.30  595.05
#
# [100 rows x 5 columns]

# %%
from sklearn.metrics import precision_score

# %%
preds = model.predict(test[predictors])

# %%
preds = pd.Series(preds , index=test.index)

# %%
preds
# Out:
# Date
# 2023-07-12    1
# 2023-07-13    1
# 2023-07-14    1
# 2023-07-17    0
# 2023-07-18    1
#              ..
# 2023-11-29    0
# 2023-11-30    1
# 2023-12-01    1
# 2023-12-04    1
# 2023-12-05    0
# Length: 100, dtype: int32

# %%
precision_score(test['Target'],preds)
# Out:
# 0.6027397260273972

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2000, step=252):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    1239
# 1     954
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5335429769392034

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.509804
# 0    0.490196
# Name: count, dtype: float64

# %%
print(df.dtypes)
# Out:
# Open        float64
# High        float64
# Low         float64
# Close       float64
# Volume        int64
# Tomorrow    float64
# Target        int32
# dtype: object

# %%
df = df.dropna(subset=['Close'])
df
# Out:
#               Open    High     Low   Close    Volume  Tomorrow  Target
# Date
# 2007-01-02  125.00  126.00  124.30  125.36   4081440    126.49       1
# 2007-01-03  125.00  126.99  123.71  126.49   6825540    124.30       0
# 2007-01-04  127.00  128.00  123.72  124.30   6544400    124.41       1
# 2007-01-05  124.10  125.78  123.31  124.41   6962270    121.37       0
# 2007-01-08  124.88  124.88  120.71  121.37   8747010    117.49       0
# ...            ...     ...     ...     ...       ...       ...     ...
# 2023-11-29  568.00  569.00  565.10  568.60  10299034    564.75       0
# 2023-11-30  569.75  570.20  563.65  564.75  19758998    571.75       1
# 2023-12-01  567.00  574.20  566.55  571.75  10614230    594.70       1
# 2023-12-04  588.00  596.00  584.55  594.70  26077882    608.25       1
# 2023-12-05  595.05  611.30  595.05  608.25  36430152       NaN       0
#
# [4193 rows x 7 columns]

# %%
horizons = [2,5,60,252,3000]
new_predictors = []

for horizon in horizons:
    rolling_averages = df.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    df[ratio_column] = df["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    df[trend_column] = df.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors+= [ratio_column, trend_column]

# %%
 df = df.dropna(subset=df.columns[df.columns != "Tomorrow"])
df
# Out:
#               Open    High     Low   Close    Volume  Tomorrow  Target
# Date
# 2019-02-11  285.95  285.95  280.00  280.50  15420017    275.40       0  \
# 2019-02-12  280.65  282.20  274.65  275.40  15326106    268.20       0
# 2019-02-13  276.50  276.70  266.70  268.20  18662893    267.10       0
# 2019-02-14  268.00  268.35  263.65  267.10  26372671    262.95       0
# 2019-02-15  268.85  268.85  261.30  262.95  23366091    259.95       0
# ...            ...     ...     ...     ...       ...       ...     ...
# 2023-11-29  568.00  569.00  565.10  568.60  10299034    564.75       0
# 2023-11-30  569.75  570.20  563.65  564.75  19758998    571.75       1
# 2023-12-01  567.00  574.20  566.55  571.75  10614230    594.70       1
# 2023-12-04  588.00  596.00  584.55  594.70  26077882    608.25       1
# 2023-12-05  595.05  611.30  595.05  608.25  36430152       NaN       0
#
#             Close_Ratio_2  Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60
# Date
# 2019-02-11       0.990291      0.0       0.982418      2.0        0.967291  \
# 2019-02-12       0.990826      0.0       0.970846      1.0        0.950551
# 2019-02-13       0.986755      0.0       0.959571      0.0        0.926764
# 2019-02-14       0.997945      0.0       0.969721      0.0        0.923833
# 2019-02-15       0.992171      0.0       0.970904      0.0        0.910744
# ...                   ...      ...            ...      ...             ...
# 2023-11-29       1.003663      2.0       1.010916      4.0        0.982229
# 2023-11-30       0.996603      1.0       1.002005      4.0        0.975713
# 2023-12-01       1.006159      1.0       1.010195      4.0        0.987915
# 2023-12-04       1.019675      2.0       1.038143      4.0        1.026928
# 2023-12-05       1.011264      2.0       1.045804      4.0        1.049186
#
#             Trend_60  Close_Ratio_252  Trend_252  Close_Ratio_3000  Trend_3000
# Date
# 2019-02-11      28.0         1.022718      118.0          1.266834      1509.0
# 2019-02-12      27.0         1.004453      117.0          1.243522      1508.0
# 2019-02-13      27.0         0.978526      117.0          1.210750      1508.0
# 2019-02-14      27.0         0.974875      116.0          1.205525      1507.0
# 2019-02-15      26.0         0.960263      115.0          1.186542      1507.0
# ...              ...              ...        ...               ...         ...
# 2023-11-29      36.0         0.990572      135.0          1.855806      1531.0
# 2023-11-30      35.0         0.984168      134.0          1.842497      1530.0
# 2023-12-01      35.0         0.996613      135.0          1.864570      1530.0
# 2023-12-04      36.0         1.036716      135.0          1.938562      1531.0
# 2023-12-05      37.0         1.060340      136.0          1.981818      1532.0
#
# [1193 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >=.6] =1
    preds[preds <.6] =0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=1000, step=252):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    184
# 1.0      9
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5555555555555556

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.559585
# 0    0.440415
# Name: count, dtype: float64

# %%
predictions
# Out:
#             Target  Predictions
# Date
# 2023-02-22       1          0.0
# 2023-02-23       1          0.0
# 2023-02-24       1          0.0
# 2023-02-27       0          0.0
# 2023-02-28       1          0.0
# ...            ...          ...
# 2023-11-29       0          0.0
# 2023-11-30       1          0.0
# 2023-12-01       1          0.0
# 2023-12-04       1          0.0
# 2023-12-05       0          0.0
#
# [193 rows x 2 columns]

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# from tensorflow.keras.models import Sequential

# %%
# df['close'].plot.line(use_index= True)
# df['predicted'][valid_point+31:].plot.line(use_index= True)
# plt.title("Axis bank")
# plt.legend(['Actual',"Predicted"])
# plt.show()
# Out:
# 21/21 [==============================] - 1s 12ms/step

# %%
df['close'].plot.line(use_index= True)
df['predicted'][valid_point+31:].plot.line(use_index= True)
plt.title("Axis bank")
plt.legend(['Actual',"Predicted"])
plt.show()

# %%
np.nan
# Out:
# <module 'numpy' from 'C:\\Users\\ksrma\\anaconda3\\envs\\ml\\lib\\site-packages\\numpy\\__init__.py'>

# %%
df=pd.read_csv("HDFCBANK.csv")

# %%
# Out:
#             Date     open     high      low    close    volume  unknown
# 12    2020-11-04  1252.00  1264.80  1230.00  1257.40  11702411        0
# 13    2020-11-03  1226.45  1250.75  1225.50  1247.95  14082115        0
# 14    2020-11-02  1194.35  1225.00  1177.50  1215.25  10963040        0
# 15    2020-10-30  1182.55  1199.30  1176.35  1183.55   5761470        0
# 16    2020-10-29  1200.60  1204.45  1178.50  1187.20  11530152        0
# ...          ...      ...      ...      ...      ...       ...      ...
# 3436  2007-01-08   105.40   105.40   101.65   102.50   3107030        0
# 3437  2007-01-05   105.47   107.39   103.42   105.69   5954670        0
# 3438  2007-01-04   105.60   106.50   103.50   105.00   3433420        0
# 3439  2007-01-03   106.80   107.00   105.31   106.53   1516050        0
# 3440  2007-01-02   107.98   107.98   106.50   107.00   2016770        0
#
# [3429 rows x 7 columns]

# %%
# Out:
# datetime.date(2020, 11, 4)

# %%
x_test.shape
# Out:
# (658, 30, 1)

# %%
np.array(df['Date'][len(df)-30:]).reshape(1,30,1)
# Out:
# array([[['2007-02-14'],
#         ['2007-02-13'],
#         ['2007-02-12'],
#         ['2007-02-09'],
#         ['2007-02-08'],
#         ['2007-02-07'],
#         ['2007-02-06'],
#         ['2007-02-05'],
#         ['2007-02-02'],
#         ['2007-02-01'],
#         ['2007-01-31'],
#         ['2007-01-29'],
#         ['2007-01-25'],
#         ['2007-01-24'],
#         ['2007-01-23'],
#         ['2007-01-22'],
#         ['2007-01-19'],
#         ['2007-01-18'],
#         ['2007-01-17'],
#         ['2007-01-16'],
#         ['2007-01-15'],
#         ['2007-01-12'],
#         ['2007-01-11'],
#         ['2007-01-10'],
#         ['2007-01-09'],
#         ['2007-01-08'],
#         ['2007-01-05'],
#         ['2007-01-04'],
#         ['2007-01-03'],
#         ['2007-01-02']]], dtype=object)

# %%
data=get_hist_data('NSE_EQ|INE238A01034','2021-05-21','2021-06-20')

# %%
data
# Out:
# []
