# %%
import upstox_client 
import pandas as pd
import numpy as np

# %%
api_instance = upstox_client.HistoryApi()
instrument_key = 'NSE_EQ|INE238A01034'# str | Key of the instrument NSE_EQ|INE238A01034,NSE_INDEX|Nifty Bank

interval = 'day'
to_date ='2023-11-24'
from_date ='1990-11-08'
api_version = '2.0' # str | API Version Header
api_response = api_instance.get_historical_candle_data1(instrument_key,interval,to_date,from_date,api_version)

# %%
data=api_response.data.candles

# %%
data
# Out:
# [['2023-11-24T00:00:00+05:30', 1002, 1010.75, 999.7, 1008.5, 6956281, 0],
#  ['2023-11-23T00:00:00+05:30', 999, 1003.4, 995.4, 999.05, 3112891, 0],
#  ['2023-11-22T00:00:00+05:30', 991, 999.9, 988, 998.1, 6103988, 0],
#  ['2023-11-21T00:00:00+05:30', 989.95, 997.5, 986.65, 991.8, 7061614, 0],
#  ['2023-11-20T00:00:00+05:30', 981, 994.75, 980.35, 988.7, 8215656, 0],
#  ['2023-11-17T00:00:00+05:30', 1014.9, 1020, 991.85, 994.35, 13268353, 0],
#  ['2023-11-16T00:00:00+05:30', 1042.8, 1044, 1022.15, 1026.35, 6908825, 0],
#  ['2023-11-15T00:00:00+05:30', 1045, 1045, 1031.55, 1041.35, 7240388, 0],
#  ['2023-11-13T00:00:00+05:30', 1030.05, 1031.85, 1023.5, 1025.35, 5985481, 0],
#  ['2023-11-12T00:00:00+05:30', 1033.9, 1033.9, 1026.25, 1029.95, 461834, 0],
#  ['2023-11-10T00:00:00+05:30', 1017.9, 1031, 1016.65, 1029.2, 3294063, 0],
#  ['2023-11-09T00:00:00+05:30', 1024.75, 1028.85, 1016.65, 1021.9, 4407935, 0],
#  ['2023-11-08T00:00:00+05:30', 1024, 1026.95, 1015.6, 1021.7, 7643314, 0],
# ...

# %%
df=pd.DataFrame(data,columns=['Date',"open","high","low","close","volume","unknown"])

# %%
df
# Out:
#                            Date     open     high     low    close   volume  \
# 0     2023-11-24T00:00:00+05:30  1002.00  1010.75  999.70  1008.50  6956281
# 1     2023-11-23T00:00:00+05:30   999.00  1003.40  995.40   999.05  3112891
# 2     2023-11-22T00:00:00+05:30   991.00   999.90  988.00   998.10  6103988
# 3     2023-11-21T00:00:00+05:30   989.95   997.50  986.65   991.80  7061614
# 4     2023-11-20T00:00:00+05:30   981.00   994.75  980.35   988.70  8215656
# ...                         ...      ...      ...     ...      ...      ...
# 4182  2007-01-08T00:00:00+05:30    94.40    94.40   91.80    93.11  2482595
# 4183  2007-01-05T00:00:00+05:30    94.60    96.15   93.26    94.57  1274125
# 4184  2007-01-04T00:00:00+05:30    95.98    97.00   93.82    94.85  1567750
# 4185  2007-01-03T00:00:00+05:30    93.98    95.59   93.06    94.93  1229170
# 4186  2007-01-02T00:00:00+05:30    94.36    94.36   92.26    93.58   907130
#
#       unknown
# 0           0
# 1           0
# ...

# %%
df.to_csv(r"C:\Users\Dell\Downloads\FInal Year Project\Bankniftyaxis.csv")

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4187, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4187 entries, 0 to 4186
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4187 non-null   object
#  1   open     4187 non-null   float64
#  2   high     4187 non-null   float64
#  3   low      4187 non-null   float64
#  4   close    4187 non-null   float64
#  5   volume   4187 non-null   int64
#  6   unknown  4187 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 229.1+ KB

# %%
df.describe()
# Out:
#               open         high          low        close        volume  \
# count  4187.000000  4187.000000  4187.000000  4187.000000  4.187000e+03
# mean    439.896064   445.858223   433.334688   439.559255  1.082252e+07
# std     244.982453   246.876494   242.799616   244.851592  8.945437e+06
# min      58.000000    59.340000    55.650000    56.280000  1.473900e+05
# 25%     223.940000   227.460000   220.140000   223.830000  5.702182e+06
# 50%     437.700000   444.450000   429.500000   436.100000  8.330315e+06
# 75%     624.975000   633.000000   617.400000   624.925000  1.273251e+07
# max    1045.000000  1047.500000  1032.600000  1041.350000  1.205419e+08
#
#        unknown
# count   4187.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
import matplotlib.pyplot as plt

# %%
df.plot.line(y="close", use_index= True)
# Out:
# <Axes: >

# %%
del df['unknown']

# %%
df["Tomorrow"] = df["close"].shift(-1)

# %%
df
# Out:
#                            Date     open     high     low    close   volume  \
# 0     2023-11-24T00:00:00+05:30  1002.00  1010.75  999.70  1008.50  6956281
# 1     2023-11-23T00:00:00+05:30   999.00  1003.40  995.40   999.05  3112891
# 2     2023-11-22T00:00:00+05:30   991.00   999.90  988.00   998.10  6103988
# 3     2023-11-21T00:00:00+05:30   989.95   997.50  986.65   991.80  7061614
# 4     2023-11-20T00:00:00+05:30   981.00   994.75  980.35   988.70  8215656
# ...                         ...      ...      ...     ...      ...      ...
# 4182  2007-01-08T00:00:00+05:30    94.40    94.40   91.80    93.11  2482595
# 4183  2007-01-05T00:00:00+05:30    94.60    96.15   93.26    94.57  1274125
# 4184  2007-01-04T00:00:00+05:30    95.98    97.00   93.82    94.85  1567750
# 4185  2007-01-03T00:00:00+05:30    93.98    95.59   93.06    94.93  1229170
# 4186  2007-01-02T00:00:00+05:30    94.36    94.36   92.26    93.58   907130
#
#       Tomorrow
# 0       999.05
# 1       998.10
# ...

# %%
df.isnull()
# Out:
#        Date   open   high    low  close  volume  Tomorrow
# 0     False  False  False  False  False   False     False
# 1     False  False  False  False  False   False     False
# 2     False  False  False  False  False   False     False
# 3     False  False  False  False  False   False     False
# 4     False  False  False  False  False   False     False
# ...     ...    ...    ...    ...    ...     ...       ...
# 4182  False  False  False  False  False   False     False
# 4183  False  False  False  False  False   False     False
# 4184  False  False  False  False  False   False     False
# 4185  False  False  False  False  False   False     False
# 4186  False  False  False  False  False   False      True
#
# [4187 rows x 7 columns]

# %%
df.dropna(axis=0)
# Out:
#                            Date     open     high     low    close   volume  \
# 0     2023-11-24T00:00:00+05:30  1002.00  1010.75  999.70  1008.50  6956281
# 1     2023-11-23T00:00:00+05:30   999.00  1003.40  995.40   999.05  3112891
# 2     2023-11-22T00:00:00+05:30   991.00   999.90  988.00   998.10  6103988
# 3     2023-11-21T00:00:00+05:30   989.95   997.50  986.65   991.80  7061614
# 4     2023-11-20T00:00:00+05:30   981.00   994.75  980.35   988.70  8215656
# ...                         ...      ...      ...     ...      ...      ...
# 4181  2007-01-09T00:00:00+05:30    94.00    95.00   92.01    93.45  5433595
# 4182  2007-01-08T00:00:00+05:30    94.40    94.40   91.80    93.11  2482595
# 4183  2007-01-05T00:00:00+05:30    94.60    96.15   93.26    94.57  1274125
# 4184  2007-01-04T00:00:00+05:30    95.98    97.00   93.82    94.85  1567750
# 4185  2007-01-03T00:00:00+05:30    93.98    95.59   93.06    94.93  1229170
#
#       Tomorrow
# 0       999.05
# 1       998.10
# ...

# %%
data1= df.drop_duplicates()
data1
# Out:
#                            Date     open     high     low    close   volume  \
# 0     2023-11-24T00:00:00+05:30  1002.00  1010.75  999.70  1008.50  6956281
# 1     2023-11-23T00:00:00+05:30   999.00  1003.40  995.40   999.05  3112891
# 2     2023-11-22T00:00:00+05:30   991.00   999.90  988.00   998.10  6103988
# 3     2023-11-21T00:00:00+05:30   989.95   997.50  986.65   991.80  7061614
# 4     2023-11-20T00:00:00+05:30   981.00   994.75  980.35   988.70  8215656
# ...                         ...      ...      ...     ...      ...      ...
# 4182  2007-01-08T00:00:00+05:30    94.40    94.40   91.80    93.11  2482595
# 4183  2007-01-05T00:00:00+05:30    94.60    96.15   93.26    94.57  1274125
# 4184  2007-01-04T00:00:00+05:30    95.98    97.00   93.82    94.85  1567750
# 4185  2007-01-03T00:00:00+05:30    93.98    95.59   93.06    94.93  1229170
# 4186  2007-01-02T00:00:00+05:30    94.36    94.36   92.26    93.58   907130
#
#       Tomorrow
# 0       999.05
# 1       998.10
# ...

# %%
df.isna().sum()
# Out:
# Date        0
# open        0
# high        0
# low         0
# close       0
# volume      0
# Tomorrow    1
# dtype: int64

# %%
df=df.dropna()

# %%
df["Target"] = (df['Tomorrow'] > df['close']).astype(int)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14516\1975377583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Target"] = (df['Tomorrow'] > df['close']).astype(int)

# %%
df = df.loc['2021-11-08' :].copy()

# %%
df
# Out:
#                            Date    open    high     low   close    volume  \
# 2022  2015-09-23T00:00:00+05:30  498.75  514.85  497.10  511.70   7602683
# 2023  2015-09-22T00:00:00+05:30  531.00  534.70  505.20  509.70   7358434
# 2024  2015-09-21T00:00:00+05:30  510.55  530.00  508.75  528.00   7516002
# 2025  2015-09-18T00:00:00+05:30  500.00  520.40  500.00  517.45  18814281
# 2026  2015-09-16T00:00:00+05:30  487.45  497.00  486.00  494.25   7293528
# ...                         ...     ...     ...     ...     ...       ...
# 4181  2007-01-09T00:00:00+05:30   94.00   95.00   92.01   93.45   5433595
# 4182  2007-01-08T00:00:00+05:30   94.40   94.40   91.80   93.11   2482595
# 4183  2007-01-05T00:00:00+05:30   94.60   96.15   93.26   94.57   1274125
# 4184  2007-01-04T00:00:00+05:30   95.98   97.00   93.82   94.85   1567750
# 4185  2007-01-03T00:00:00+05:30   93.98   95.59   93.06   94.93   1229170
#
#       Tomorrow  Target
# 2022    509.70       0
# 2023    528.00       1
# ...

# %%
Training the model
# Out:
#   Cell In [189], line 1
#     Training the model
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = df.iloc[:-100]
test = df.iloc[-100:]

predictors = ['close', 'volume', 'open', 'high', 'low']
model.fit(train[predictors], train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

# %%
preds = model.predict(test[predictors])

# %%
preds = pd.Series(preds , index=test.index)

# %%
preds
# Out:
# 4086    0
# 4087    0
# 4088    1
# 4089    0
# 4090    0
#        ..
# 4181    0
# 4182    0
# 4183    1
# 4184    1
# 4185    1
# Length: 100, dtype: int32

# %%
precision_score(test['Target'],preds)
# Out:
# 0.5

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: >
